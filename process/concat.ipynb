# %%
import pandas as pd

f1 = pd.read_csv('output/2014_all_process.csv')
f2 = pd.read_csv('output/2016_all_process.csv')
f3 = pd.read_csv('output/2018_all_process.csv')
file = [f1,f2,f3]
df = pd.concat(file)

df.describe().T
# Out:
#                   count          mean           std          min          25%  \
# Unnamed: 0      99473.0  2.140797e+04  1.609247e+04          0.0       8289.0
# pid             99473.0  3.725706e+08  1.566078e+08  100051501.0  220284103.0
# fid             99473.0  3.731593e+05  1.790546e+05     100051.0     220075.0
# mate_hukou      99242.0 -1.865017e+00  4.742568e+00         -8.0         -8.0
# mate_edu        99231.0 -7.726718e-01  5.231079e+00         -9.0         -8.0
# mate_age        99245.0  2.814048e+01  2.799825e+01         -9.0         -8.0
# pid_f           99473.0  1.643244e+08  2.082027e+08         -8.0         -8.0
# pid_m           99473.0  1.733896e+08  2.112475e+08         -8.0         -8.0
# mate_pid        99473.0  2.470014e+08  2.174066e+08         -8.0         -8.0
# hukou_parent_f  26094.0 -3.239787e+00  4.784109e+00         -8.0         -8.0
# parent_f_age    26106.0  3.800126e+01  3.810866e+01         -9.0         -8.0
# ...

# %%
df.to_csv('output/all_process.csv')
